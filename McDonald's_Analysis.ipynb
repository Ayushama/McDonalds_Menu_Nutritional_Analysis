# %% [markdown]
# #  Analysis Project

# %% [markdown]
# By : Ayush Aman
#
# Project Title: NutriCal : McDonald's Menu Nutritional Analysis

# %% [markdown]
# # Contents of the Projects
# - Introduction
# - Problem Statement
# - Import necessory libraries
# - Analysing and Understanding Data
#     - Analysing Rows and Cols
#     - Analysing type of dataframe
#     - Printing all columns of dataframe
#     - Information about data columns and its type
#     - Printing of top rows
#     - Data Cleaning and Manipulation
# - Checking duplicate values
#     - Checking null values
# - Exploratory Data Analysis(EDA)
# - Analyze the distribution of calorie counts across menu items.
#     - Explore the Nutrition content (e.g. fat,protein carbohydrates) of different Items.
# - Data Visualization
# - Categorical Variable Analysis
#     - Numerical Variable Analyasis
# - Nutrition-Based Insights:
#     - Identify menu items with the highest and lowest calorie counts.
#
# Introduction: In this project we have to extract meaningful information from the McDonalds menu nutritional dataset. and we have to perform exploratory data analysis to understand the nutritional distribution and trends. using Visualization we have to present the present calorie count and nutrition facts of different menu items. we have to find healthy and less healthy menu options. Problem Statement : McDonalds Global fast-food chain is offering a diverse menu. As a Data analyst we have to analyse the Nutritional content of the menu item avilable at McDonalds outlets.

# %% [markdown]
# # import necessory libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
data_dir= "D:/DA/Python/McDonald's"

# %% [markdown]
# # import os to check the directory structure

# %%
import os
os.listdir(data_dir)
# Out:
# ['Nutrical Dataset workbook.xlsx', 'Nutrical Dataset.csv']

# %% [markdown]
# # import data from excel file and load into df dataframe

# %%
#df=pd.read_excel(data_dir+"/Nutrical_Dataset.xlsx")
df = pd.read_csv(data_dir + "/Nutrical Dataset.csv")

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# # Print all columns of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#Check for duplicate value
df[df.duplicated()].count().sum()
# Out:
# 0

# %%
#checking the missing values if any exists
print(df.isnull().any())
# Out:
# Category                         False
# Item                             False
# Serving Size                     False
# Calories                         False
# Calories from Fat                False
# Total Fat                        False
# Total Fat (% Daily Value)        False
# Saturated Fat                    False
# Saturated Fat (% Daily Value)    False
# Trans Fat                        False
# Cholesterol                      False
# Cholesterol (% Daily Value)      False
# Sodium                           False
# Sodium (% Daily Value)           False
# Carbohydrates                    False
# Carbohydrates (% Daily Value)    False
# Dietary Fiber                    False
# Dietary Fiber (% Daily Value)    False
# Sugars                           False
# Protein                          False
# Vitamin A (% Daily Value)        False
# Vitamin C (% Daily Value)        False
# Calcium (% Daily Value)          False
# Iron (% Daily Value)             False
# dtype: bool

# %% [markdown]
# # Information about data columns and its data type

# %%
#Load and inspect the dataset
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
#Handle missing values and data cleaning
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
#checking no of rows and cols
df.shape
# Out:
# (260, 24)

# %%
#checking type of df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Print all columns of dataframe
df.keys()
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
print(df['Category'].unique())
# Out:
# ['Breakfast' 'Beef & Pork' 'Chicken & Fish' 'Salads' 'Snacks & Sides'
#  'Desserts' 'Beverages' 'Coffee & Tea' 'Smoothies & Shakes']

# %%
print(df['Item'].unique())
# Out:
# ['Egg McMuffin' 'Egg White Delight' 'Sausage McMuffin'
#  'Sausage McMuffin with Egg' 'Sausage McMuffin with Egg Whites'
#  'Steak & Egg McMuffin' 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)'
#  'Bacon, Egg & Cheese Biscuit (Large Biscuit)'
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)'
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)'
#  'Sausage Biscuit (Regular Biscuit)' 'Sausage Biscuit (Large Biscuit)'
#  'Sausage Biscuit with Egg (Regular Biscuit)'
#  'Sausage Biscuit with Egg (Large Biscuit)'
#  'Sausage Biscuit with Egg Whites (Regular Biscuit)'
#  'Sausage Biscuit with Egg Whites (Large Biscuit)'
#  'Southern Style Chicken Biscuit (Regular Biscuit)'
#  'Southern Style Chicken Biscuit (Large Biscuit)'
#  'Steak & Egg Biscuit (Regular Biscuit)' 'Bacon, Egg & Cheese McGriddles'
#  'Bacon, Egg & Cheese McGriddles with Egg Whites' 'Sausage McGriddles'
#  'Sausage, Egg & Cheese McGriddles'
#  'Sausage, Egg & Cheese McGriddles with Egg Whites'
# ...

# %% [markdown]
# # Pie chart for values count in each Category

# %%
df.Category.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Category and Quantity wise Bar Chart

# %%
def barplot(variable):
    var=df[variable]
    varval=var.value_counts()
    plt.figure(figsize=(10,3))
    plt.bar(varval.index,varval)
    plt.xticks(rotation=45,ha='right')
    plt.xticks(varval.index,varval.index.values)
    plt.ylabel("Friquency")
    plt.title(variable)
    plt.show()

categories=["Category"]
for a in categories:
    barplot(a)

# %% [markdown]
# # Checking the outliers

# %%
#checking the outliers
plt.figure(figsize=(15,12))
plt.subplot(3,1,1)
sns.boxplot(x=df['Calories'],color='lightgreen')

plt.subplot(3,1,2)
sns.boxplot(x=df['Calories from Fat'],color='lightgreen')

plt.subplot(3,1,3)
sns.boxplot(x=df['Cholesterol'],color='lightgreen')

plt.show()

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#  #  Analyze the distribution of calorie

# %%
mean_calories = df['Calories'].mean()
median_calories = df['Calories'].median()
mode_calories = df['Calories'].mode().values[0]
std_calories = df['Calories'].std()

print(f"Mean: {mean_calories}")
print(f"Median: {median_calories}")
print(f"Mode: {mode_calories}")
print(f"Standard Deviation: {std_calories}")
# Out:
# Mean: 368.2692307692308
# Median: 340.0
# Mode: 0
# Standard Deviation: 240.26988649145852

# %%
Item_values = df[['Calories','Total Fat','Carbohydrates','Dietary Fiber','Sugars','Protein',
                 'Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']].max()

print(Item_values)
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %%
# Explore nutritional content
average_nutrition = df.groupby('Category')[['Sugars','Protein', 'Calories', 'Carbohydrates']].mean()

# %% [markdown]
# ## Distribution of Calories Counts across the Menu Items

# %%
# Identify trends and patterns
# Creating histograms plot for Visualisation
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=20, kde=True)
plt.title('Distribution of Calorie Counts')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Explore the nutritional content (e.g., fat, protein, carbohydrates) of different items.

# %%
nutritional_columns = ['Total Fat', 'Protein', 'Carbohydrates']

nutritional_stats = df[nutritional_columns].describe()
print(nutritional_stats)
# Out:
#         Total Fat     Protein  Carbohydrates
# count  260.000000  260.000000     260.000000
# mean    14.165385   13.338462      47.346154
# std     14.205998   11.426146      28.252232
# min      0.000000    0.000000       0.000000
# 25%      2.375000    4.000000      30.000000
# 50%     11.000000   12.000000      44.000000
# 75%     22.250000   19.000000      60.000000
# max    118.000000   87.000000     141.000000

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[nutritional_columns])
plt.title('Distribution of Nutritional Content')
plt.ylabel('Grams')
plt.show()

# %%
# Correlation matrix
correlation_matrix = df[nutritional_columns].corr()

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Nutritional Content')
plt.show()

# %% [markdown]
# # Barplot for comparing Unique_category and their Calories

# %%
sns.barplot(data=df,x='Category',y='Calories')
plt.xticks(rotation=45,ha='right')
plt.title("Unique Category VS Calories")

plt.show()

# %% [markdown]
# # Nutrition-Based Insights:

# %%
calorie_df = df[['Item','Calories','Total Fat']]
calorie_df.min()
# Out:
# Item         1% Low Fat Milk Jug
# Calories                       0
# Total Fat                    0.0
# dtype: object

# %%
calorie_df.max()
# Out:
# Item         Vanilla Shake (Small)
# Calories                      1880
# Total Fat                    118.0
# dtype: object

# %%
Sugar_df = df[['Item','Sugars','Carbohydrates']]
Sugar_df.min()
# Out:
# Item             1% Low Fat Milk Jug
# Sugars                             0
# Carbohydrates                      0
# dtype: object

# %%
Sugar_df.max()
# Out:
# Item             Vanilla Shake (Small)
# Sugars                             128
# Carbohydrates                      141
# dtype: object

# %%
Carbohydrates_df= df[['Item','Carbohydrates','Total Fat']]
Carbohydrates_df.max()
# Out:
# Item             Vanilla Shake (Small)
# Carbohydrates                      141
# Total Fat                        118.0
# dtype: object

# %%
Carbohydrates_df.min()
# Out:
# Item             1% Low Fat Milk Jug
# Carbohydrates                      0
# Total Fat                        0.0
# dtype: object

# %% [markdown]
# # Determine the average nutritional content of popular menu categories.

# %%
# Assuming I have a DataFrame named average_nutrition with columns like 'Category', 'Sugars', 'Calories', 'Carbohydrates'

# Calculate the average nutritional content by menu category
average_nutrition = df.groupby('Category')[['Sugars','Protein', 'Calories', 'Carbohydrates']].mean()


# Display the result
print("Average Nutritional Content by Menu Category:")
print(average_nutrition)
# Out:
# Average Nutritional Content by Menu Category:
#                        Sugars    Protein    Calories  Carbohydrates
# Category
# Beef & Pork          8.800000  27.333333  494.000000      40.133333
# Beverages           27.851852   1.333333  113.703704      28.814815
# Breakfast            8.261905  19.857143  526.666667      49.761905
# Chicken & Fish       7.333333  29.111111  552.962963      49.074074
# Coffee & Tea        39.610526   8.863158  283.894737      44.526316
# Desserts            26.142857   4.000000  222.142857      34.857143
# Salads               6.833333  19.833333  270.000000      21.666667
# Smoothies & Shakes  77.892857  10.857143  531.428571      90.428571
# Snacks & Sides       4.076923   8.384615  245.769231      29.153846

# %% [markdown]
# # Conclusion
#    - According to the count of serving Size and Calories the Chicken and Fish has the heighest Calories.
#    - Create bar charts, histograms, and box plots to visualize calorie distribution and nutritional content.

# %%
# Create a bar chart to visualize the distribution of calories by category
plt.figure(figsize=(12, 6))
sns.barplot(x='Category', y='Calories', data=df)
plt.title('Calorie Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## Create a histogram to visualize the distribution of calories

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=20, kde=True)
plt.title('Distribution of Calorie Counts')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Create a box plot to visualize the distribution of nutritional content.

# %%
nutritional_columns = ['Total Fat', 'Protein', 'Carbohydrates']

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[nutritional_columns])
plt.title('Distribution of Nutritional Content')
plt.ylabel('Grams')
plt.show()

# %% [markdown]
# # Compare nutritional characteristics of different food categories (e.g., burgers, salads, desserts).

# %%
# Filter data for specific categories
selected_categories = ['Burgers', 'Salads', 'Desserts']
df_selected_categories = df[df['Category'].isin(selected_categories)]

# Display basic statistics for each category
category_stats = df_selected_categories.groupby('Category').describe()

# Create bar charts to compare nutritional characteristics
nutritional_columns = ['Total Fat', 'Protein', 'Carbohydrates']

for nutrient in nutritional_columns:
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Category', y=nutrient, data=df_selected_categories)
    plt.title(f'{nutrient} Content in Burgers, Salads, and Desserts')
    plt.xlabel('Category')
    plt.ylabel(f'{nutrient} (g)')
    plt.show()

# %% [markdown]
# # Identify menu items with the highest and lowest calorie counts.

# %%
highest_calories = df.nlargest(5, 'Calories')  
lowest_calories = df.nsmallest(5, 'Calories')  

print("Menu Items with the Highest Calorie Counts:")
print(highest_calories[['Item', 'Calories']])

print("\nMenu Items with the Lowest Calorie Counts:")
print(lowest_calories[['Item', 'Calories']])
# Out:
# Menu Items with the Highest Calorie Counts:
#                                                  Item  Calories
# 82                       Chicken McNuggets (40 piece)      1880
# 32        Big Breakfast with Hotcakes (Large Biscuit)      1150
# 31      Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 34  Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 33  Big Breakfast with Hotcakes and Egg Whites (Re...       990
#
# Menu Items with the Lowest Calorie Counts:
#                        Item  Calories
# 114       Diet Coke (Small)         0
# 115      Diet Coke (Medium)         0
# 116       Diet Coke (Large)         0
# 117       Diet Coke (Child)         0
# 122  Diet Dr Pepper (Small)         0

# %%
# Identify menu items with the highest and lowest calorie counts.
highest_calories = df.nlargest(1, 'Calories')
highest_calories
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %%
#Conclusin : Chicken and Fish has the heighest Calories
lowest_calories = df.nsmallest(1, 'Calories')
lowest_calories
# Out:
#       Category               Item  Serving Size  Calories  Calories from Fat  \
# 114  Beverages  Diet Coke (Small)  16 fl oz cup         0                  0
#
#      Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 114        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 114                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 114                              0              0
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 114                              0       0        0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 114                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 114                        0                     0
#
# [1 rows x 24 columns]

# %% [markdown]
# # Conclusion : Beverages has the lowest calories

# %% [markdown]
# ## Overall Conclusion :
# - Breakfast items are required to be the healthiest in the whole menu. Although McDonald tries to update and introduce healthy item lime for example food items and vegetables, there is still lot of imbalance in the content. McDonald should reduce cholesterol and sodium in breakfast items.
# - Nuggets is found to be the unhealthiest food with respect to unsaturated fat and cholesterol and this could be one of the reason for overweight children who feed McDonalds on a regular basis.
# - Although people convern about how McDonalds influence badly on their health, it is also a chance for McDonalds. This company can develop new products.
# - McDonald should introduce healthy breakfast separately for kids that can be fresh juices, non deep fried meat and vegetables with high protein.

# %% [markdown]
# # Marketing, and quality assurance, contributes to a more health-conscious and customer-centric approach.
